# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
# Out:
# /Users/troycassels/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
cd /Users/troycassels/Documents
# Out:
# /Users/troycassels/Documents

# %%
file_path = "Documents"

# %%
df = pd.read_csv(Path("Sample GPT tweets.csv"))

# %%
df.head()
# Out:
#            user_name                                               text  \
# 0        Math_Maniac  ChatGPT does ascii art\n#ChatGPT https://t.co/...
# 1        SmashKoders  #ChatGPT is funny sometimes 😅 https://t.co/cSa...
# 2  Andreas Illenseer  Let’s put it in graphic terms. Drawing a #Unic...
# 3       Bitone Great  🔥#Buy!🔥\n🔥RSI below 15!🔥\n[#Bybit]\n⬆ Recommen...
# 4    The Media Scoop  Italian data protection agency placed an immed...
#
#         user_location                                   user_description  \
# 0         Decatur, GA  I work with a number of tools. Right now it's ...
# 1              Mumbai             My life changed while debugging code 😊
# 2  Mainz, Deutschland  Specialized in Regulatory & Digital Intelligen...
# 3                 NaN  #ChatGPT (AI) powered Free Trading Signal! \nL...
# 4               India  Independent news aggregator & YouTuber at The ...
#
#                 user_created  user_followers  user_friends  user_favourites  \
# 0  2020-07-20 14:24:50+00:00           467.0        1233.0            49216
# 1  2022-06-18 04:34:18+00:00             8.0         126.0              239
# 2  2017-10-31 19:35:24+00:00            63.0         188.0               88
# 3  2022-11-21 04:42:18+00:00          1093.0         492.0               47
# 4  2023-03-07 01:51:53+00:00             0.0          37.0                0
#
#    user_verified                       date  \
# 0          False  2023-04-02 13:44:07+00:00
# 1          False  2023-04-02 13:43:46+00:00
# 2          False  2023-04-02 13:43:36+00:00
# 3          False  2023-04-02 13:43:30+00:00
# 4          False  2023-04-02 13:42:56+00:00
#
#                                hashtags              source
# 0                           ['ChatGPT']     Twitter Web App
# 1                           ['ChatGPT']     Twitter Web App
# 2                           ['Unicorn']  Twitter for iPhone
# 3  ['Buy', 'Bybit', 'Long', 'DODOUSDT']                rsi1
# 4                                   NaN     Twitter Web App

# %%
df.iloc[0]
# Out:
# user_name                                                 Math_Maniac
# text                ChatGPT does ascii art\n#ChatGPT https://t.co/...
# user_location                                             Decatur, GA
# user_description    I work with a number of tools. Right now it's ...
# user_created                                2020-07-20 14:24:50+00:00
# user_followers                                                  467.0
# user_friends                                                   1233.0
# user_favourites                                                 49216
# user_verified                                                   False
# date                                        2023-04-02 13:44:07+00:00
# hashtags                                                  ['ChatGPT']
# source                                                Twitter Web App
# Name: 0, dtype: object

# %%
df["user_created"] =df["user_created"].apply(lambda x: pd.Timestamp(x).timestamp())

# %%
df["date"] =df["date"].apply(lambda x: pd.Timestamp(x).timestamp())

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia= SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/troycassels/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df['scores']=df['text'].apply(lambda body: sia.polarity_scores(str(body)))

# %%
df.head()
# Out:
#            user_name                                               text  \
# 0        Math_Maniac  ChatGPT does ascii art\n#ChatGPT https://t.co/...
# 1        SmashKoders  #ChatGPT is funny sometimes 😅 https://t.co/cSa...
# 2  Andreas Illenseer  Let’s put it in graphic terms. Drawing a #Unic...
# 3       Bitone Great  🔥#Buy!🔥\n🔥RSI below 15!🔥\n[#Bybit]\n⬆ Recommen...
# 4    The Media Scoop  Italian data protection agency placed an immed...
#
#         user_location                                   user_description  \
# 0         Decatur, GA  I work with a number of tools. Right now it's ...
# 1              Mumbai             My life changed while debugging code 😊
# 2  Mainz, Deutschland  Specialized in Regulatory & Digital Intelligen...
# 3                 NaN  #ChatGPT (AI) powered Free Trading Signal! \nL...
# 4               India  Independent news aggregator & YouTuber at The ...
#
#    user_created  user_followers  user_friends  user_favourites  user_verified  \
# 0  1.595255e+09           467.0        1233.0            49216          False
# 1  1.655527e+09             8.0         126.0              239          False
# 2  1.509479e+09            63.0         188.0               88          False
# 3  1.669006e+09          1093.0         492.0               47          False
# 4  1.678154e+09             0.0          37.0                0          False
#
#            date                              hashtags              source  \
# 0  1.680443e+09                           ['ChatGPT']     Twitter Web App
# 1  1.680443e+09                           ['ChatGPT']     Twitter Web App
# 2  1.680443e+09                           ['Unicorn']  Twitter for iPhone
# 3  1.680443e+09  ['Buy', 'Bybit', 'Long', 'DODOUSDT']                rsi1
# 4  1.680443e+09                                   NaN     Twitter Web App
#
#                                               scores
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compou...
# 2  {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'comp...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.107, 'neu': 0.893, 'pos': 0.0, 'comp...

# %%
df.iloc[0]
# Out:
# user_name                                                 Math_Maniac
# text                ChatGPT does ascii art\n#ChatGPT https://t.co/...
# user_location                                             Decatur, GA
# user_description    I work with a number of tools. Right now it's ...
# user_created                                             1595255090.0
# user_followers                                                  467.0
# user_friends                                                   1233.0
# user_favourites                                                 49216
# user_verified                                                   False
# date                                                     1680443047.0
# hashtags                                                  ['ChatGPT']
# source                                                Twitter Web App
# scores              {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# Name: 0, dtype: object

# %%
df.dtypes
# Out:
# user_name            object
# text                 object
# user_location        object
# user_description     object
# user_created        float64
# user_followers      float64
# user_friends        float64
# user_favourites       int64
# user_verified          bool
# date                float64
# hashtags             object
# source               object
# scores               object
# dtype: object

# %%
X_not_categorical = df[["user_created","user_followers","user_friends","user_favourites","date"]]
X_not_categorical.head()
# Out:
#    user_created  user_followers  user_friends  user_favourites          date
# 0  1.595255e+09           467.0        1233.0            49216  1.680443e+09
# 1  1.655527e+09             8.0         126.0              239  1.680443e+09
# 2  1.509479e+09            63.0         188.0               88  1.680443e+09
# 3  1.669006e+09          1093.0         492.0               47  1.680443e+09
# 4  1.678154e+09             0.0          37.0                0  1.680443e+09

# %%
X_categorical_exc_location = df[["user_verified","source"]]
X_categorical_exc_location.head()
# Out:
#    user_verified              source
# 0          False     Twitter Web App
# 1          False     Twitter Web App
# 2          False  Twitter for iPhone
# 3          False                rsi1
# 4          False     Twitter Web App

# %%
X_categorical_exc_location = pd.get_dummies(X_categorical_exc_location)
X_categorical_exc_location.head()
# Out:
#    user_verified  source_Buffer  source_Constant Contact - Social Posts  \
# 0          False              0                                       0
# 1          False              0                                       0
# 2          False              0                                       0
# 3          False              0                                       0
# 4          False              0                                       0
#
#    source_Hootsuite Inc.  source_IFTTT  source_Make (formerly Integromat)  \
# 0                      0             0                                  0
# 1                      0             0                                  0
# 2                      0             0                                  0
# 3                      0             0                                  0
# 4                      0             0                                  0
#
#    source_Metricool  source_Missinglettr  source_Nelio Content  \
# 0                 0                    0                     0
# 1                 0                    0                     0
# 2                 0                    0                     0
# 3                 0                    0                     0
# 4                 0                    0                     0
#
#    source_SocialChamp IO   source_Sprout Social  source_TweetDeck  \
# 0                       0                     0                 0
# 1                       0                     0                 0
# 2                       0                     0                 0
# 3                       0                     0                 0
# 4                       0                     0                 0
#
#    source_Twitter Web App  source_Twitter for Android  \
# 0                       1                           0
# 1                       1                           0
# 2                       0                           0
# 3                       0                           0
# 4                       1                           0
#
#    source_Twitter for iPhone  source_rsi1
# 0                          0            0
# 1                          0            0
# 2                          1            0
# 3                          0            1
# 4                          0            0

# %%
X = pd.concat([X_not_categorical, X_categorical_exc_location], axis=1)
X.head()
# Out:
#    user_created  user_followers  user_friends  user_favourites          date  \
# 0  1.595255e+09           467.0        1233.0            49216  1.680443e+09
# 1  1.655527e+09             8.0         126.0              239  1.680443e+09
# 2  1.509479e+09            63.0         188.0               88  1.680443e+09
# 3  1.669006e+09          1093.0         492.0               47  1.680443e+09
# 4  1.678154e+09             0.0          37.0                0  1.680443e+09
#
#    user_verified  source_Buffer  source_Constant Contact - Social Posts  \
# 0          False              0                                       0
# 1          False              0                                       0
# 2          False              0                                       0
# 3          False              0                                       0
# 4          False              0                                       0
#
#    source_Hootsuite Inc.  source_IFTTT  ...  source_Metricool  \
# 0                      0             0  ...                 0
# 1                      0             0  ...                 0
# 2                      0             0  ...                 0
# 3                      0             0  ...                 0
# 4                      0             0  ...                 0
#
#    source_Missinglettr  source_Nelio Content  source_SocialChamp IO   \
# 0                    0                     0                       0
# 1                    0                     0                       0
# 2                    0                     0                       0
# 3                    0                     0                       0
# 4                    0                     0                       0
#
#    source_Sprout Social  source_TweetDeck  source_Twitter Web App  \
# 0                     0                 0                       1
# 1                     0                 0                       1
# 2                     0                 0                       0
# 3                     0                 0                       0
# 4                     0                 0                       1
#
#    source_Twitter for Android  source_Twitter for iPhone  source_rsi1
# 0                           0                          0            0
# 1                           0                          0            0
# 2                           0                          1            0
# 3                           0                          0            1
# 4                           0                          0            0
#
# [5 rows x 21 columns]

# %%
def vader_scores(text, category):
    return vader.polarity_scores(text).get(category)

vader = SentimentIntensityAnalyzer()

df["Negative_Score"] = df.apply(lambda row : vader_scores(df["text"][row.name], "neg"),axis=1)
df["Neutral_Score"] = df.apply(lambda row : vader_scores(df["text"][row.name], "neu"),axis=1)
df["Positive_Score"] = df.apply(lambda row : vader_scores(df["text"][row.name], "pos"),axis=1)
df["Compound_Score"] = df.apply(lambda row : vader_scores(df["text"][row.name], "compound"),axis=1)

# %%
df.head(10)
# Out:
#                      user_name  \
# 0                  Math_Maniac
# 1                  SmashKoders
# 2            Andreas Illenseer
# 3                 Bitone Great
# 4              The Media Scoop
# 5  Game Development Daily News
# 6               Simon Hodgkins
# 7                       Khaled
# 8                  Vivek Ahuja
# 9                   Myindianow
#
#                                                 text            user_location  \
# 0  ChatGPT does ascii art\n#ChatGPT https://t.co/...              Decatur, GA
# 1  #ChatGPT is funny sometimes 😅 https://t.co/cSa...                   Mumbai
# 2  Let’s put it in graphic terms. Drawing a #Unic...       Mainz, Deutschland
# 3  🔥#Buy!🔥\n🔥RSI below 15!🔥\n[#Bybit]\n⬆ Recommen...                      NaN
# 4  Italian data protection agency placed an immed...                    India
# 5  Will your games be marketed by ChatGPT? https:...                      NaN
# 6  Italian minister says country's ban on ChatGPT...  Global | Ireland | USA
# 7  https://t.co/MBDVVcTrqW . For Sale :\n\n🔥 Suit...                      NaN
# 8  How to keep your start-up relevant in 2023:\n\...            Mumbai, India
# 9  ChatGPT will not replace people. But people wh...              Pune, India
#
#                                     user_description  user_created  \
# 0  I work with a number of tools. Right now it's ...  1.595255e+09
# 1             My life changed while debugging code 😊  1.655527e+09
# 2  Specialized in Regulatory & Digital Intelligen...  1.509479e+09
# 3  #ChatGPT (AI) powered Free Trading Signal! \nL...  1.669006e+09
# 4  Independent news aggregator & YouTuber at The ...  1.678154e+09
# 5  Your source for daily news about game developm...  1.599147e+09
# 6        President | Founder | CMO | Editor in Chief  1.287299e+09
# 7  https://t.co/WamqNL2OVC  https://t.co/kZaVTeRp...  1.580991e+09
# 8  Run an Audio Production House | Manage Artists...  1.475162e+09
# 9                                                 🇮🇳  1.646190e+09
#
#    user_followers  user_friends  user_favourites  user_verified          date  \
# 0           467.0        1233.0            49216          False  1.680443e+09
# 1             8.0         126.0              239          False  1.680443e+09
# 2            63.0         188.0               88          False  1.680443e+09
# 3          1093.0         492.0               47          False  1.680443e+09
# 4             0.0          37.0                0          False  1.680443e+09
# 5          2525.0         724.0             1108          False  1.680443e+09
# 6          6364.0         296.0            23528          False  1.680443e+09
# 7          1306.0         564.0             7763          False  1.680443e+09
# 8             8.0          88.0               32          False  1.680443e+09
# 9            14.0          33.0               52          False  1.680443e+09
#
#                                             hashtags               source  \
# 0                                        ['ChatGPT']      Twitter Web App
# 1                                        ['ChatGPT']      Twitter Web App
# 2                                        ['Unicorn']   Twitter for iPhone
# 3               ['Buy', 'Bybit', 'Long', 'DODOUSDT']                 rsi1
# 4                                                NaN      Twitter Web App
# 5  ['gamedev', 'gamedevelopment', 'indiedev', 'AI...      Twitter Web App
# 6                                                NaN   Twitter for iPhone
# 7                                           ['Meta']      Twitter Web App
# 8                                        ['ChatGPT']      Twitter Web App
# 9                     ['ChatGPT', 'OpenAI', 'AIart']  Twitter for Android
#
#                                               scores  Negative_Score  \
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...           0.000
# 1  {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compou...           0.000
# 2  {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'comp...           0.000
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...           0.000
# 4  {'neg': 0.107, 'neu': 0.893, 'pos': 0.0, 'comp...           0.107
# 5  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...           0.000
# 6  {'neg': 0.104, 'neu': 0.896, 'pos': 0.0, 'comp...           0.104
# 7  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'comp...           0.000
# 8  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...           0.000
# 9  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...           0.000
#
#    Neutral_Score  Positive_Score  Compound_Score
# 0          1.000           0.000          0.0000
# 1          0.580           0.420          0.4404
# 2          0.857           0.143          0.7574
# 3          1.000           0.000          0.0000
# 4          0.893           0.000         -0.5574
# 5          1.000           0.000          0.0000
# 6          0.896           0.000         -0.5574
# 7          0.909           0.091          0.4767
# 8          1.000           0.000          0.0000
# 9          1.000           0.000          0.0000

# %%
df.tail(10)
# Out:
#                                             user_name  \
# 90                                       Bitone Great
# 91  Dr. Monika Sonu I Founder Healthinnovationtoolbox
# 92                                       Bitone Great
# 93                                        Pirate Mike
# 94                                         Most Bay▶️
# 95                                           fracksix
# 96                                    Kalina Kalinova
# 97                                  Sundar Narasimhan
# 98                                         Most Bay▶️
# 99                                     Alvaro Ramirez
#
#                                                  text  \
# 90  🚨Time to Buy!🚨\n💰#Binance Spot💰\n⬆️ Recommenda...
# 91  #AI News &amp; Highlights: March 2023 \nby Ste...
# 92  🚨Get In!🚨\n💰#Binance Spot💰\n⬆️ Recommendation:...
# 93  #ChatGPT is a tool do not become dependent upo...
# 94  RiverRise(.)com SOLD for $2,288 -BuyDomains, A...
# 95   #ChatGPT cannot save us. https://t.co/tmAMM5zdzu
# 96  FREE Social Ping Submission 138 Directories\nh...
# 97  Great discussion at @theallinpod esp. regardin...
# 98  ClientFinancing(.)com SOLD for $2,288 -BuyDoma...
# 99  chatgpt-shell now offers a post-processing cus...
#
#                     user_location  \
# 90                            NaN
# 91                      Bangalore
# 92                            NaN
# 93                    Bristol, VA
# 94                   JakartaX.com
# 95                            NaN
# 96                            NaN
# 97                            NaN
# 98                   JakartaX.com
# 99  In Emacs, somewhere in London
#
#                                      user_description  user_created  \
# 90  #ChatGPT (AI) powered Free Trading Signal! \nL...  1.669006e+09
# 91  HIMSSFUTURE50-INNOVATION LEADER  https://t.co/...  1.533366e+09
# 92  #ChatGPT (AI) powered Free Trading Signal! \nL...  1.669006e+09
# 93  Author | Crypto Educator | Investor | Mental H...  1.665755e+09
# 94  Investor in #Crypto & #DomainNames. Selling: h...  1.347730e+09
# 95                                                NaN  1.678213e+09
# 96                                                NaN  1.675222e+09
# 97                                                NaN  1.329684e+09
# 98  Investor in #Crypto & #DomainNames. Selling: h...  1.347730e+09
# 99                            https://t.co/cWRvlp5UQ0  1.267626e+09
#
#     user_followers  user_friends  user_favourites  user_verified  \
# 90          1093.0         492.0               47          False
# 91         15822.0       12403.0            29194          False
# 92          1093.0         492.0               47          False
# 93           513.0        4935.0             1698          False
# 94          2343.0        4338.0            15594          False
# 95             3.0          28.0                0          False
# 96           107.0         387.0              249          False
# 97            99.0        1058.0             1175          False
# 98          2343.0        4338.0            15594          False
# 99           523.0        1097.0             1251          False
#
#             date                                           hashtags  \
# 90  1.680441e+09                    ['Binance', 'Long', 'IOTXUSDT']
# 91  1.680441e+09  ['AI', 'technology', 'data', 'ArtificialIntell...
# 92  1.680441e+09                    ['Binance', 'Long', 'ARPAUSDT']
# 93  1.680441e+09                                        ['ChatGPT']
# 94  1.680441e+09                                                NaN
# 95  1.680441e+09                                        ['ChatGPT']
# 96  1.680441e+09  ['FREE', 'Social', 'Ping', 'Submission', 'Dire...
# 97  1.680441e+09                                                NaN
# 98  1.680441e+09                                                NaN
# 99  1.680441e+09                                                NaN
#
#                  source                                             scores  \
# 90                 rsi1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 91      Twitter Web App  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 92                 rsi1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 93   Twitter for iPhone  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 94      Twitter Web App  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 95   Twitter for iPhone  {'neg': 0.396, 'neu': 0.604, 'pos': 0.0, 'comp...
# 96      Twitter Web App  {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'comp...
# 97  Twitter for Android  {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'comp...
# 98      Twitter Web App  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 99      Twitter Web App  {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'comp...
#
#     Negative_Score  Neutral_Score  Positive_Score  Compound_Score
# 90           0.000          1.000           0.000          0.0000
# 91           0.000          1.000           0.000          0.0000
# 92           0.000          1.000           0.000          0.0000
# 93           0.000          1.000           0.000          0.0000
# 94           0.000          1.000           0.000          0.0000
# 95           0.396          0.604           0.000         -0.3875
# 96           0.000          0.776           0.224          0.6166
# 97           0.000          0.866           0.134          0.7096
# 98           0.000          1.000           0.000          0.0000
# 99           0.000          0.902           0.098          0.3612

# %%
y = df["Compound_Score"]

# %%
y.head()
# Out:
# 0    0.0000
# 1    0.4404
# 2    0.7574
# 3    0.0000
# 4   -0.5574
# Name: Compound_Score, dtype: float64

# %%
X.head()
# Out:
#    user_created  user_followers  user_friends  user_favourites          date  \
# 0  1.595255e+09           467.0        1233.0            49216  1.680443e+09
# 1  1.655527e+09             8.0         126.0              239  1.680443e+09
# 2  1.509479e+09            63.0         188.0               88  1.680443e+09
# 3  1.669006e+09          1093.0         492.0               47  1.680443e+09
# 4  1.678154e+09             0.0          37.0                0  1.680443e+09
#
#    user_verified  source_Buffer  source_Constant Contact - Social Posts  \
# 0          False              0                                       0
# 1          False              0                                       0
# 2          False              0                                       0
# 3          False              0                                       0
# 4          False              0                                       0
#
#    source_Hootsuite Inc.  source_IFTTT  ...  source_Metricool  \
# 0                      0             0  ...                 0
# 1                      0             0  ...                 0
# 2                      0             0  ...                 0
# 3                      0             0  ...                 0
# 4                      0             0  ...                 0
#
#    source_Missinglettr  source_Nelio Content  source_SocialChamp IO   \
# 0                    0                     0                       0
# 1                    0                     0                       0
# 2                    0                     0                       0
# 3                    0                     0                       0
# 4                    0                     0                       0
#
#    source_Sprout Social  source_TweetDeck  source_Twitter Web App  \
# 0                     0                 0                       1
# 1                     0                 0                       1
# 2                     0                 0                       0
# 3                     0                 0                       0
# 4                     0                 0                       1
#
#    source_Twitter for Android  source_Twitter for iPhone  source_rsi1
# 0                           0                          0            0
# 1                           0                          0            0
# 2                           0                          1            0
# 3                           0                          0            1
# 4                           0                          0            0
#
# [5 rows x 21 columns]

# %%
# Split data into training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Instantiate a StandardScaler instance
scaler = StandardScaler()

# Fit the training data to the standard scaler
X_scaler = scaler.fit(X_train)

# Transform the training data using the scaler
X_train_scaled = X_scaler.transform(X_train)

# Transform the testing data using the scaler
X_test_scaled = X_scaler.transform(X_test)
